# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.7 MB 16.9 MB/s eta 0:00:01
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 16.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 26.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 895 kB 30.0 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import os

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#   file_name  COVID
# 0     0.png      0
# 1     1.png      1
# 2     2.png      0
# 3     3.png      1
# 4     4.png      1

# %%
train.shape
# Out:
# (646, 2)

# %%
len(train)
# Out:
# 646

# %%
train.loc[1]
# Out:
# file_name    1.png
# COVID            1
# Name: 1, dtype: object

# %%
train['COVID'].value_counts()
# Out:
# 0    342
# 1    304
# Name: COVID, dtype: int64

# %%
# train
imgpath = 'data/train'
pos = train.loc[train['COVID']==1]['file_name'].values
neg = train.loc[train['COVID']==0]['file_name'].values

nrows, ncols = 3, 10
fig, ax = plt.subplots(nrows, ncols, figsize=(13, 4))
for i,j in enumerate(pos[:nrows*ncols]):
    fname = os.path.join(imgpath, j)
    img = Image.open(fname)
    idcol = ImageDraw.Draw(img)
    plt.subplot(nrows, ncols, i+1) 
    plt.imshow(np.array(img))
    plt.axis('off')

# %%
fig, ax = plt.subplots(nrows, ncols, figsize=(15, 3))
for i,j in enumerate(neg[:nrows*ncols]):
    fname = os.path.join(imgpath, j)
    img = Image.open(fname)
    idcol = ImageDraw.Draw(img)
    plt.subplot(nrows, ncols, i+1) 
    plt.imshow(np.array(img))
    plt.axis('off')

# %%
# test
fig, ax = plt.subplots(nrows, ncols, figsize=(15, 3))
for i in range(20):
    fname = os.path.join('data/test', str(i) + '.png')
    img = Image.open(fname)
    idcol = ImageDraw.Draw(img)
    plt.subplot(nrows, ncols, i+1)
    plt.imshow(np.array(img))
    plt.axis('off')

# %%
sub = pd.read_csv('sample_submission.csv')
sub.head()
# Out:
#   file_name  COVID
# 0     0.png      0
# 1     1.png      0
# 2     2.png      0
# 3     3.png      0
# 4     4.png      0

# %%
sub.shape
# Out:
# (100, 2)
